# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 14

# %%
# KDD Accuracy
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_DoS', 'Miss_Probe','Miss_R2L', 'Miss_U2R']
algorithms = ['RF-IDS', 'SVM-IDS', 'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#6886af', '#d7adbe', '#116594', '#242d62', '#adb7dc', '#b6c6db',  '#c56477']

accuracy = {
    'Miss_DoS': [85.15 ,82.82 ,77.46 ,81.31 ,74.72 ,84.99 ,85.28 ],
    'Miss_Probe': [84.90 ,84.34 ,73.85 ,73.31 ,77.48 ,83.63 ,85.07 ],
    'Miss_R2L': [83.75 ,81.93 ,81.47 ,78.69 ,57.35 ,82.21 ,85.17 ],
    'Miss_U2R': [84.85 ,82.19 ,79.25 ,82.15 ,70.39 ,82.21 ,85.40 ]
}

    

    

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.4)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('Accuracy (%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('NSL_KDD_Accuracy.png', dpi=300, bbox_inches='tight')
# plt.show()

# %%
# KDD UDR
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_DoS', 'Miss_Probe','Miss_R2L', 'Miss_U2R']
algorithms = ['RF-IDS', 'SVM-IDS',  'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#6886af', '#d7adbe',  '#116594', '#242d62',  '#adb7dc', '#b6c6db', '#c56477']

accuracy = {
    'Miss_DoS': [82.35, 85.32, 72.33, 73.09, 72.33, 94.68, 97.63],
    'Miss_Probe': [94.01, 89.05, 29.29, 14.58, 81.74, 87.73, 94.01],
    'Miss_R2L': [78.35, 62.21, 74.26, 43.30, 35.05, 50.81, 99.38],
    'Miss_U2R': [29.85, 22.39, 19.40, 80.60, 35.82, 58.21, 100.00]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.5)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('UDR (%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('NSL_KDD_UDR.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# KDD Recall
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_DoS', 'Miss_Probe','Miss_R2L', 'Miss_U2R']
algorithms = ['RF-IDS', 'SVM-IDS', 'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#6886af', '#d7adbe', '#116594', '#242d62', '#adb7dc', '#b6c6db',  '#c56477']

accuracy = {
    'Miss_DoS': [76.04 ,79.30 ,64.68 ,73.08 ,56.30 ,83.00 ,83.54 ],
    'Miss_Probe': [79.30 ,76.80 ,55.04 ,52.04 ,61.14 ,80.00 ,82.68 ],
    'Miss_R2L': [94.82 ,87.56 ,85.40 ,78.52 ,20.90 ,85.70 ,97.24 ],
    'Miss_U2R': [73.74 ,79.64 ,66.18 ,80.40 ,53.80 ,74.00 ,84.42 ],
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.4)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('Recall(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('NSL_KDD_Recall.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# KDD Precision
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_DoS', 'Miss_Probe','Miss_R2L', 'Miss_U2R']
algorithms = ['RF-IDS', 'SVM-IDS', 'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#6886af', '#d7adbe', '#116594', '#242d62', '#adb7dc', '#b6c6db',  '#c56477']

accuracy = {
    'Miss_DoS': [92.98, 85.31, 86.89, 87.48, 89.14, 86.44, 86.55],
    'Miss_Probe': [89.30, 90.44, 88.23, 90.57, 90.82, 86.26, 86.83],
    'Miss_R2L': [77.63, 78.70, 79.18, 78.79, 77.12, 80.11, 78.33],
    'Miss_U2R': [94.81, 83.92, 89.60, 83.32, 80.51, 88.54, 86.11]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.4)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('Precision(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('NSL_KDD_Precision.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# KDD F1-Score
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_DoS', 'Miss_Probe','Miss_R2L', 'Miss_U2R']
algorithms = ['RF-IDS', 'SVM-IDS', 'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#6886af', '#d7adbe', '#116594', '#242d62', '#adb7dc', '#b6c6db',  '#c56477']

accuracy = {
    'Miss_DoS': [83.66, 82.19, 74.16, 79.63, 69.01, 84.69, 85.02],
    'Miss_Probe': [84.00, 83.06, 67.79, 66.10, 73.08, 83.01, 84.70],
    'Miss_R2L': [85.37, 82.83, 82.17, 78.65, 32.89, 82.81, 86.77],
    'Miss_U2R': [82.96, 81.72, 76.13, 81.83, 64.50, 80.62, 85.26]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.4)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('F1-Score(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('NSL_KDD_F1-Score.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# UNSW UDR
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_A', 'Miss_B','Miss_D', 'Miss_E','Miss_F','Miss_G','Miss_R','Miss_S','Miss_W']
algorithms = ['RF-IDS', 'SVM-IDS', 'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#7492b7', '#2c4875', '#789b8c', '#003f5c', '#8a508f', '#bc5090',  '#c56477']

accuracy = {
    'Miss_A': [91.43,  	90.99 ,88.18 ,91.43 ,90.40 ,91.43 ,100.00 ],
    'Miss_B': [94.51 ,85.94 ,97.60 ,98.80 ,90.05 ,90.74 ,99.83 ],
    'Miss_D': [93.84 ,96.57 ,83.27 ,93.62 ,75.35 ,71.56 ,98.19 ],
    'Miss_E': [64.58 ,47.14 ,84.11 ,66.91 ,26.82 ,29.44 ,89.68 ],
    'Miss_F': [32.51 ,28.19 ,40.02 ,55.43 ,42.43 ,38.73 ,74.94 ],
    'Miss_G': [46.74 ,42.02 ,41.20 ,72.27 ,91.57 ,97.15 ,99.69 ],
    'Miss_R': [90.73 ,90.33 ,54.29 ,83.38 ,24.97 ,46.02 ,92.33 ],
    'Miss_S': [92.59 ,78.31 ,80.16 ,90.48 ,48.68 ,44.71 ,100.00 ],
    'Miss_W': [86.36 ,40.91 ,86.36 ,95.45 ,22.73 ,13.64 ,100.00 ]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.4)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('UDR(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('UNSW_UDR.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# UNSW Accuracy
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_A', 'Miss_B','Miss_D', 'Miss_E','Miss_F','Miss_G','Miss_R','Miss_S','Miss_W']
algorithms = ['RF-IDS', 'SVM-IDS', 'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#7492b7', '#2c4875', '#789b8c', '#003f5c', '#8a508f', '#bc5090',  '#c56477']

accuracy = {
    'Miss_A': [89.64 ,73.02 ,80.76 ,81.31 ,78.88 ,77.83 ,90.48 ],
    'Miss_B': [88.60 ,73.99 ,81.16 ,82.18 ,78.88 ,77.71 ,89.87 ],
    'Miss_D': [88.19 ,73.34 ,75.69 ,81.72 ,78.88 ,77.35 ,90.24 ],
    'Miss_E': [85.51 ,77.37 ,81.95 ,80.85 ,76.93 ,77.31 ,90.00 ],
    'Miss_F': [88.94 ,57.46 ,82.61 ,81.83 ,78.88 ,76.89 ,89.87 ],
    'Miss_G': [75.66 ,67.10 ,68.11 ,75.54 ,69.97 ,77.51 ,91.27 ],
    'Miss_R': [88.66 ,80.81 ,75.13 ,82.04 ,78.88 ,77.43 ,91.25 ],
    'Miss_S': [88.08 ,80.67 ,82.81 ,82.21 ,71.22 ,77.84 ,92.01 ],
    'Miss_W': [88.86 ,78.43 ,85.67 ,81.41 ,76.71 ,78.36 ,90.66 ]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.4)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('Accuracy(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('UNSW_Accuracy.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# UNSW Precision
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_A', 'Miss_B','Miss_D', 'Miss_E','Miss_F','Miss_G','Miss_R','Miss_S','Miss_W']
algorithms = ['RF-IDS', 'SVM-IDS', 'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#7492b7', '#2c4875', '#789b8c', '#003f5c', '#8a508f', '#bc5090',  '#c56477']

accuracy = {
    'Miss_A': [90.06 ,81.06 ,76.23 ,77.73 ,87.18 ,87.48 ,90.51 ],
    'Miss_B': [93.45 ,76.08 ,80.38 ,79.02 ,87.18 ,86.20 ,90.93 ],
    'Miss_D': [88.46 ,77.92 ,74.75 ,78.62 ,87.18 ,85.83 ,91.18 ],
    'Miss_E': [87.37 ,77.66 ,80.64 ,80.13 ,86.03 ,85.57 ,90.73 ],
    'Miss_F': [91.01 ,64.94 ,81.05 ,78.30 ,87.18 ,84.47 ,91.51 ],
    'Miss_G': [77.53 ,69.05 ,68.16 ,74.03 ,70.66 ,86.07 ,91.44 ],
    'Miss_R': [88.97 ,83.01 ,79.12 ,80.50 ,87.18 ,86.24 ,91.41 ],
    'Miss_S': [85.90 ,82.37 ,80.10 ,78.68 ,74.61 ,87.60 ,91.44 ],
    'Miss_W': [91.38 ,78.76 ,85.24 ,77.86 ,85.95 ,87.79 ,91.29 ]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.4)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('Precision(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('UNSW_Precision.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# UNSW Recall
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_A', 'Miss_B','Miss_D', 'Miss_E','Miss_F','Miss_G','Miss_R','Miss_S','Miss_W']
algorithms = ['RF-IDS', 'SVM-IDS', 'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#7492b7', '#2c4875', '#789b8c', '#003f5c', '#8a508f', '#bc5090',  '#c56477']

accuracy = {
    'Miss_A': [89.12 ,60.08 ,89.40 ,87.76 ,67.72 ,64.96 ,90.44 ],
    'Miss_B': [83.02 ,69.98 ,82.44 ,87.62 ,67.72 ,65.98 ,88.58 ],
    'Miss_D': [87.84 ,65.14 ,77.58 ,87.14 ,67.72 ,65.52 ,89.10 ],
    'Miss_E': [83.02 ,76.84 ,84.08 ,82.04 ,64.30 ,65.70 ,89.10 ],
    'Miss_F': [86.42 ,32.42 ,85.12 ,88.06 ,67.72 ,65.90 ,87.90 ],
    'Miss_G': [72.26 ,61.98 ,67.98 ,78.68 ,68.30 ,65.64 ,91.06 ],
    'Miss_R': [88.26 ,77.48 ,68.28 ,84.56 ,67.72 ,65.28 ,91.06 ],
    'Miss_S': [91.12 ,78.04 ,87.32 ,88.36 ,64.34 ,64.86 ,92.70 ],
    'Miss_W': [85.82 ,77.86 ,86.28 ,87.78 ,63.86 ,65.88 ,89.90 ]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.4)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('Recall(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('UNSW_Recall.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# UNSW F1-Score
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_A', 'Miss_B','Miss_D', 'Miss_E','Miss_F','Miss_G','Miss_R','Miss_S','Miss_W']
algorithms = ['RF-IDS', 'SVM-IDS', 'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#7492b7', '#2c4875', '#789b8c', '#003f5c', '#8a508f', '#bc5090',  '#c56477']

accuracy = {
    'Miss_A': [89.59 ,69.01 ,82.29 ,82.44 ,76.23 ,74.56 ,90.48 ],
    'Miss_B': [87.93 ,72.90 ,81.40 ,83.10 ,76.23 ,74.75 ,89.74 ],
    'Miss_D': [88.15 ,70.96 ,76.14 ,82.66 ,76.23 ,74.31 ,90.13 ],
    'Miss_E': [85.14 ,77.25 ,82.33 ,81.08 ,73.60 ,74.33 ,89.91 ],
    'Miss_F': [88.65 ,43.25 ,83.04 ,82.90 ,76.23 ,74.04 ,89.67 ],
    'Miss_G': [74.80 ,65.32 ,68.07 ,76.28 ,69.46 ,74.48 ,91.25 ],
    'Miss_R': [88.61 ,80.15 ,73.30 ,82.48 ,76.23 ,74.31 ,91.23 ],
    'Miss_S': [88.43 ,80.15 ,83.55 ,83.24 ,69.09 ,74.53 ,92.06 ],
    'Miss_W': [88.51 ,78.31 ,85.76 ,82.52 ,73.28 ,75.27 ,90.59 ]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.4)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('F1-Score(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('UNSW_F1-Score.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# UNSW FPR
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_A', 'Miss_B','Miss_D', 'Miss_E','Miss_F','Miss_G','Miss_R','Miss_S','Miss_W']
algorithms = ['RF-IDS', 'SVM-IDS', 'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#7492b7', '#2c4875', '#789b8c', '#003f5c', '#8a508f', '#bc5090',  '#c56477']

accuracy = {
    'Miss_A': [9.84 ,14.04 ,27.88 ,25.14 ,9.96 ,9.30 ,9.48 ],
    'Miss_B': [5.82 ,22.00 ,20.12 ,23.26 ,9.96 ,10.56 ,8.84 ],
    'Miss_D': [11.46 ,18.46 ,26.20 ,23.70 ,9.96 ,10.82 ,8.62 ],
    'Miss_E': [12.00 ,22.10 ,20.18 ,20.34 ,10.44 ,11.08 ,9.10 ],
    'Miss_F': [8.54 ,17.50 ,19.90 ,24.40 ,9.96 ,12.12 ,8.16 ],
    'Miss_G': [20.94 ,27.78 ,31.76 ,27.60 ,28.36 ,10.62 ,8.52 ],
    'Miss_R': [10.94 ,15.86 ,18.02 ,20.48 ,9.96 ,10.42 ,8.56 ],
    'Miss_S': [14.96 ,16.70 ,21.70 ,23.94 ,21.90 ,9.18 ,8.68 ],
    'Miss_W': [8.10 ,21.00 ,14.94 ,24.96 ,10.44 ,9.16 ,8.58 ]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.4)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('FPR(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('UNSW_FPR.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# CICIDS2018 UDR
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_DoS', 'Miss_Bruteforce','Miss_DDoS', 'Miss_Infiltration','Miss_SQL_Injection']
algorithms = ['RF-IDS', 'SVM-IDS',  'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#1e4a28', '#cc7a3d', '#51a16a', '#a0c4ff', '#ffc6ff', '#d6eadf','#c56477']

accuracy = {
    'Miss_Bot': [47.68 	,48.30 	,50.12 ,	0.02 ,	0.03 	,49.85 ,	100.00 ],
    'Miss_Bruteforce': [46.20 ,37.20 ,33.60 ,19.60 ,25.60 ,58.80 ,100.00 ],
    'Miss_DDoS': [56.25 ,24.17 ,0.03 ,0.00 ,23.89 ,99.76 ,100.00 ],
    'Miss_DoS': [21.35 ,15.35 ,9.27 ,1.90 ,0.00 ,27.65 ,41.48 ],
    'Miss_Infiltration': [14.94 ,35.68 ,21.83 ,0.04 ,19.94 ,26.27 ,79.70 ],
    'Miss_SQL_Injection': [49.25 ,43.28 ,64.18 ,73.13 ,0.00 ,56.72 ,100.00 ]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.5)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('UDR(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('CICIDS2018_UDR.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# CICIDS2018 Accuracy
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_DoS', 'Miss_Bruteforce','Miss_DDoS', 'Miss_Infiltration','Miss_SQL_Injection']
algorithms = ['RF-IDS', 'SVM-IDS',  'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#1e4a28', '#cc7a3d', '#51a16a', '#a0c4ff', '#ffc6ff', '#d6eadf','#c56477']

accuracy = {
    'Miss_Bot': [70.02 ,74.70 ,75.95 ,53.62 ,48.38 ,48.99 ,77.25 ],
    'Miss_Bruteforce': [73.50 ,62.94 ,50.71 ,34.04 ,46.43 ,49.22 ,75.52 ],
    'Miss_DDoS': [69.43 ,59.95 ,64.12 ,40.82 ,46.37 ,52.81 ,77.07 ],
    'Miss_DoS': [54.65 ,54.81 ,49.20 ,38.84 ,48.38 ,54.62 ,77.10 ],
    'Miss_Infiltration': [75.52 ,67.88 ,67.64 ,50.18 ,37.31 ,54.55 ,77.63 ],
    'Miss_SQL_Injection': [59.76 ,61.81 ,62.97 ,36.32 ,45.04 ,48.78 ,75.06 ]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.5)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('Accuracy(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('CICIDS2018_Accuracy.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# CICIDS2018 Precision
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_DoS', 'Miss_Bruteforce','Miss_DDoS', 'Miss_Infiltration','Miss_SQL_Injection']
algorithms = ['RF-IDS', 'SVM-IDS',  'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#1e4a28', '#cc7a3d', '#51a16a', '#a0c4ff', '#ffc6ff', '#d6eadf','#c56477']

accuracy = {
    'Miss_Bot': [68.31 ,78.77 ,80.35 ,66.54 ,42.29 ,48.24 ,77.77 ],
    'Miss_Bruteforce': [76.83 ,66.78 ,51.25 ,23.84 ,21.35 ,48.98 ,75.13 ],
    'Miss_DDoS': [69.52 ,62.01 ,64.53 ,38.99 ,38.62 ,54.53 ,77.47 ],
    'Miss_DoS': [58.61 ,70.06 ,48.88 ,20.85 ,42.29 ,58.24 ,77.60 ],
    'Miss_Infiltration': [81.12 ,67.44 ,76.23 ,87.50 ,17.44 ,58.87 ,80.49 ],
    'Miss_SQL_Injection': [60.69 ,70.60 ,63.63 ,37.58 ,9.48 ,47.92 ,74.41 ]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.5)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('Precision(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('CICIDS2018_Precision.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# CICIDS2018 Recall
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_DoS', 'Miss_Bruteforce','Miss_DDoS', 'Miss_Infiltration','Miss_SQL_Injection']
algorithms = ['RF-IDS', 'SVM-IDS',  'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#1e4a28', '#cc7a3d', '#51a16a', '#a0c4ff', '#ffc6ff', '#d6eadf','#c56477']

accuracy = {
    'Miss_Bot': [74.68 ,67.62 ,68.70 ,14.56 ,8.88 ,27.66 ,76.32 ],
    'Miss_Bruteforce': [67.30 ,51.50 ,29.08 ,14.54 ,2.66 ,37.62 ,76.30 ],
    'Miss_DDoS': [69.20 ,51.38 ,62.72 ,32.52 ,12.32 ,33.82 ,76.34 ],
    'Miss_DoS': [31.66 ,16.80 ,34.78 ,7.98 ,8.88 ,32.66 ,76.20 ],
    'Miss_Infiltration': [66.52 ,69.14 ,51.26 ,0.42 ,6.80 ,30.20 ,72.94 ],
    'Miss_SQL_Injection': [55.42 ,50.76 ,60.56 ,41.40 ,1.16 ,28.14 ,76.40 ]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.5)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('Recall(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('CICIDS2018_Recall.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# CICIDS2018 F1-Score
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_DoS', 'Miss_Bruteforce','Miss_DDoS', 'Miss_Infiltration','Miss_SQL_Injection']
algorithms = ['RF-IDS', 'SVM-IDS',  'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#1e4a28', '#cc7a3d', '#51a16a', '#a0c4ff', '#ffc6ff', '#d6eadf','#c56477']

accuracy = {
    'Miss_Bot': [71.35 ,72.77 ,74.07 ,23.89 ,14.68 ,35.16 ,77.04 ],
    'Miss_Bruteforce': [71.75 ,58.15 ,37.11 ,18.06 ,4.73 ,42.56 ,75.51 ],
    'Miss_DDoS': [69.36 ,56.20 ,63.61 ,35.46 ,18.68 ,41.75 ,76.90 ],
    'Miss_DoS': [41.11 ,27.10 ,40.64 ,11.54 ,14.68 ,41.85 ,76.89 ],
    'Miss_Infiltration': [73.10 ,68.28 ,61.30 ,0.84 ,9.79 ,39.92 ,76.53 ],
    'Miss_SQL_Injection': [57.93 ,59.06 ,62.06 ,39.40 ,2.07 ,35.46 ,75.39 ]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.5)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('F1-Score(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('CICIDS2018_F1-Score.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# CICIDS2018 FPR
import matplotlib.pyplot as plt
import numpy as np

settings = ['Miss_DoS', 'Miss_Bruteforce','Miss_DDoS', 'Miss_Infiltration','Miss_SQL_Injection']
algorithms = ['RF-IDS', 'SVM-IDS',  'CNN_LSTM-IDS','GRU_LSTM-IDS','VD-IDS','DGA-PSO-IDS','LLM-IDS']
colors = ['#1e4a28', '#cc7a3d', '#51a16a', '#a0c4ff', '#ffc6ff', '#d6eadf','#c56477']

accuracy = {
    'Miss_Bot': [34.64 ,18.22 ,16.80 ,7.32 ,12.12 ,29.68 ,21.82 ],
    'Miss_Bruteforce': [20.30 ,25.62 ,27.66 ,46.46 ,9.80 ,39.18 ,25.26 ],
    'Miss_DDoS': [30.34 ,31.48 ,34.48 ,50.88 ,19.58 ,28.20 ,22.20 ],
    'Miss_DoS': [22.36 ,7.18 ,36.38 ,30.30 ,12.12 ,23.42 ,22.00 ],
    'Miss_Infiltration': [15.48 ,33.38 ,15.98 ,0.06 ,32.18 ,21.10 ,17.69 ],
    'Miss_SQL_Injection': [35.90 ,21.14 ,34.62 ,68.76 ,11.08 ,30.58 ,26.28 ]
}

n_settings = len(settings)
n_algorithms = len(algorithms) 
bar_width = 0.06
group_width = 0.4
bar_gap = 0.02

index = np.arange(n_settings) * (group_width + 0.5)
bar_positions = [index + i * (bar_width + bar_gap) for i in range(n_algorithms)]

fig, ax = plt.subplots(figsize=(8, 5)) 

ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

for i, algo in enumerate(algorithms):
    ax.bar(bar_positions[i], [accuracy[setting][i] for setting in settings], bar_width, color=colors[i], label=algo, edgecolor='black', linewidth=0.3, zorder=2)

ax.set_ylabel('FPR(%)')
ax.set_xticks(index + group_width / 2 - bar_width / 2)
ax.set_xticklabels(settings)
ax.set_ylim(0, 100)
ax.grid(axis='y', linestyle='--', alpha=0.7)

legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, frameon=True)
legend.get_frame().set_facecolor('#f0f0f0')
plt.tight_layout()
plt.savefig('CICIDS2018_FPR.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# KDD Bar
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

def plot_model_comparison(models, metrics, values, title="Model Performance Comparison", figsize=(12, 4), save_path=None):

    # 创建DataFrame以便使用seaborn
    data = []
    for i, model in enumerate(models):
        for j, metric in enumerate(metrics):
            data.append({
                'model': model,
                'metric': metric,
                'value': values[i][j] * 100
            })
    df = pd.DataFrame(data)
    
    # 设置样式
    sns.set(style="whitegrid")
    plt.figure(figsize=figsize)
    
    # 绘制条形图
    ax = sns.barplot(x='model', y='value', hue='metric', data=df)
    
    # 添加标题和标签
    plt.title(title, fontsize=16)
    plt.xlabel('', fontsize=14)
    plt.ylabel('', fontsize=14)
    plt.ylim(0, 100)  # 假设指标值在0-1之间
    
    # 在条形上方添加数值标签
    # for container in ax.containers:
    #     ax.bar_label(container, fmt='%.2f', fontsize=10)
    
    # 调整图例位置
    legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.25), ncol=6, frameon=True)
    
    plt.tight_layout()
    
    # 保存图表
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    # plt.show()

def plot_model_comparison_radar(models, metrics, values, title="model performance radar chart", figsize=(10, 8), save_path=None):

    # 设置图表
    plt.figure(figsize=figsize)
    
    # 计算雷达图的角度
    angles = np.linspace(0, 2*np.pi, len(metrics), endpoint=False).tolist()
    angles += angles[:1]  # 闭合雷达图
    
    # 设置极坐标图
    ax = plt.subplot(111, polar=True)
    
    # 添加每个模型的数据
    for i, model in enumerate(models):
        values_model = values[i]
        values_model += values_model[:1]  # 闭合雷达图
        ax.plot(angles, values_model, 'o-', linewidth=2, label=model)
        ax.fill(angles, values_model, alpha=0.1)
    
    # 设置刻度标签
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(metrics)
    
    # 设置y轴范围
    ax.set_ylim(0, 1)
    
    # 添加图例和标题
    plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
    plt.title(title, fontsize=16)
    
    plt.tight_layout()
    
    # 保存图表
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    # plt.show()

def plot_model_comparison_heatmap(models, metrics, values, title="model performance heatmap", figsize=(10, 8), save_path=None):
    # 创建数据矩阵
    data_matrix = np.array(values)
    
    # 设置图表
    plt.figure(figsize=figsize)
    
    # 绘制热力图
    ax = sns.heatmap(data_matrix, annot=True, fmt=".2f", cmap="YlGnBu",
                     xticklabels=metrics, yticklabels=models, vmin=0, vmax=1)
    
    # 添加标题和标签
    plt.title(title, fontsize=16)
    plt.tight_layout()
    
    # 保存图表
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    # plt.show()

# 模型数据
models = ['RF','SVM','CNN_LSTM','GRU_LSTM','VD','DGA-PSO','LLM']
values_DoS = [
    [0.823545186,	0.8515,	0.92981169,	0.7604,	0.836615689,	0.0574],
    [0.853177796,	0.8282,	0.853055077,	0.793,	0.821932007,	0.1366],
    [0.7232502,	0.7746,	0.868887695,	0.6468,	0.741573034,	0.0976],
    [0.730893,	0.8131,	0.87479,	0.7308,	0.79634,	0.1046],				
    [0.723250201,	0.7472,	0.891386954,	0.563,	0.690120127,	0.0686],
    [0.946768571,	0.8499,	0.864403249,	0.83,	0.846852362,	0.1302],		
    [0.9763,	0.8528,	0.8655,	0.8354,	0.8502,	0.1298]

]

values_Probe = [
    [0.940107394,	0.849,	0.893018018,	0.793,	0.840042373,	0.095],
    [0.890541099,	0.8434,	0.904380593,	0.768,	0.830629461,	0.0812],
    [0.2928542,	0.7385,	0.882334081,	0.5504,	0.677916,	0.0734],
    [0.14580752,	0.7331,	0.905673512,	0.5204,	0.660993268,	0.0542],
    [0.817430814,	0.7748,	0.908199643,	0.6114,	0.730815204,	0.0618],
    [0.87732342,	0.8363,	0.862626698,	0.8,	0.830133859,	0.1274],
    [0.9401,	0.8507,	0.8683,	0.8268,	0.847,	0.1254]
]

values_R2L = [
    [0.783512297,	0.8375,	0.776322253,	0.9482,	0.853695867,	0.2732],
    [0.6221,	0.8193,	0.787,	0.8756,	0.8283,	0.237],
    [0.7426394,	0.8147,	0.791767,	0.854,	0.82170691,	0.2246],
    [0.433,	0.7869,	0.7879,	0.7852,	0.7865,	0.2114],
    [0.35053689,	0.5735,	0.771217712,	0.209,	0.328874902,	0.062],
    [0.508139938,	0.8221,	0.801084315,	0.857,	0.828099333,	0.2128],
    [0.9938,	0.8517,	0.7833,	0.9724,	0.8677,	0.269]
]

values_U2R = [
    [0.298507463,	0.8485,	0.948058627,	0.7374,	0.82956463,	0.0404],
    [0.2239,	0.8219,	0.8392,	0.7964,	0.8172,	0.1526],
    [0.19402985,	0.7925,	0.896019496,	0.6618,	0.761302197,	0.0768],
    [0.806,	0.8215,	0.8332,	0.804,	0.8183,	0.161],
    [0.358208955,	0.7039,	0.805148159,	0.538,	0.645006594,	0.1302],
    [0.582089552,	0.8221,	0.885379277,	0.74,	0.806188038,	0.0958],		
    [1,	0.854,	0.8611,	0.8442,	0.8526,	0.1362]
]


metrics = ['UDR', 'Accuracy', 'Precision', 'Recall', 'F1-Score', 'FPR']

def plot_all_models(unknown_type):

    if unknown_type == 'DoS':
        values = values_DoS

    elif unknown_type == 'Probe':
        values = values_Probe

    elif unknown_type == 'R2L':
        values = values_R2L

    elif unknown_type == 'U2R':
        values = values_U2R


        
    # DL模型    
    plot_model_comparison(models, metrics, values, 
        title=f"NSL_KDD (Miss_{unknown_type}) Model Comparison", 
        save_path=f"NSL_KDD_{unknown_type}_model_comparison_bar.png")


plot_all_models('DoS')
plot_all_models('Probe')
plot_all_models('R2L')
plot_all_models('U2R')

# %%
# UNSW Bar
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

def plot_model_comparison(models, metrics, values, title="Model Performance Comparison", figsize=(12, 4), save_path=None):

    # 创建DataFrame以便使用seaborn
    data = []
    for i, model in enumerate(models):
        for j, metric in enumerate(metrics):
            data.append({
                'model': model,
                'metric': metric,
                'value': values[i][j] * 100
            })
    df = pd.DataFrame(data)
    
    # 设置样式
    sns.set(style="whitegrid")
    plt.figure(figsize=figsize)
    
    # 绘制条形图
    ax = sns.barplot(x='model', y='value', hue='metric', data=df)
    
    # 添加标题和标签
    plt.title(title, fontsize=16)
    plt.xlabel('', fontsize=14)
    plt.ylabel('', fontsize=14)
    plt.ylim(0, 100)  # 假设指标值在0-1之间
    
    
    # 调整图例位置
    legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.25), ncol=6, frameon=True)
    
    plt.tight_layout()
    
    # 保存图表
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    # plt.show()

def plot_model_comparison_radar(models, metrics, values, title="model performance radar chart", figsize=(10, 8), save_path=None):

    # 设置图表
    plt.figure(figsize=figsize)
    
    # 计算雷达图的角度
    angles = np.linspace(0, 2*np.pi, len(metrics), endpoint=False).tolist()
    angles += angles[:1]  # 闭合雷达图
    
    # 设置极坐标图
    ax = plt.subplot(111, polar=True)
    
    # 添加每个模型的数据
    for i, model in enumerate(models):
        values_model = values[i]
        values_model += values_model[:1]  # 闭合雷达图
        ax.plot(angles, values_model, 'o-', linewidth=2, label=model)
        ax.fill(angles, values_model, alpha=0.1)
    
    # 设置刻度标签
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(metrics)
    
    # 设置y轴范围
    ax.set_ylim(0, 1)
    
    # 添加图例和标题
    plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
    plt.title(title, fontsize=16)
    
    plt.tight_layout()
    
    # 保存图表
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    # plt.show()

def plot_model_comparison_heatmap(models, metrics, values, title="model performance heatmap", figsize=(10, 8), save_path=None):
    # 创建数据矩阵
    data_matrix = np.array(values)
    
    # 设置图表
    plt.figure(figsize=figsize)
    
    # 绘制热力图
    ax = sns.heatmap(data_matrix, annot=True, fmt=".2f", cmap="YlGnBu",
                     xticklabels=metrics, yticklabels=models, vmin=0, vmax=1)
    
    # 添加标题和标签
    plt.title(title, fontsize=16)
    plt.tight_layout()
    
    # 保存图表
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    # plt.show()

# 模型数据
models = ['RF','SVM','CNN_LSTM','GRU_LSTM','VD','DGA-PSO','LLM']
# UNSW-NB15 A
values_A = [
    [0.914327917,	0.8964,	0.900565885,	0.8912,	0.895858464,	0.0984],
    [0.909896603,	0.7302,	0.810577442,	0.6008,	0.690098782,	0.1404],
    [0.8818316,	0.8076,	0.762278308,	0.894,	0.822901325,	0.2788],
    [0.9143279,	0.8131,	0.777325066,	0.8776,	0.824424612,	0.2514],
    [0.903988183,	0.7888,	0.871781668,	0.6772,	0.762269248,	0.0996],    
    [0.914327917,	0.7783,	0.874764342,	0.6496,	0.745552623,	0.093],
    [1,	0.9048,	0.9051,	0.9044,	0.9048,	0.0948]
]

# UNSW-NB15 B
values_B = [
    [0.945111492,	0.886,	0.934488969,	0.8302,	0.879262868,	0.0582],
    [0.859378821,	0.7399,	0.760817569,	0.6998,	0.729034274,	0.22],
    [0.9759863,	0.8116,	0.803822153,	0.8244,	0.813981043,	0.2012],
    [0.9879931,	0.8218,	0.790223665,	0.8762,	0.83099393,	0.2326],
    [0.90051458,	0.7888,	0.871781668,	0.6772,	0.762269248,	0.0996],
    [0.907375643,	0.7771,	0.862032924,	0.6598,	0.747479325,	0.1056],
    [0.9983,	0.8987,	0.9093,	0.8858,	0.8974,	0.0884]
]

# UNSW-NB15 D
values_D = [
    [0.93837124,	0.8819,	0.884592145,	0.8784,	0.881485198,	0.1146],
    [0.965694683,	0.7334,	0.779186603,	0.6514,	0.709586057,	0.1846],
    [0.83272195,	0.7569,	0.747542879,	0.7758,	0.761409363,	0.262],
    [0.9361702,	0.8172,	0.786178275,	0.8714,	0.826598368,	0.237],
    [0.75348496,	0.7888,	0.871781668,	0.6772,	0.762269248,	0.0996],
    [0.715578381,	0.7735,	0.858265654,	0.6552,	0.743109901,	0.1082],
    [0.9819,	0.9024,	0.9118,	0.891,	0.9013,	0.0862]
]

# UNSW-NB15 E
values_E = [
    [0.645795904,	0.8551,	0.873710798,	0.8302,	0.851399856,	0.12],
    [0.471433705,	0.7737,	0.776632302,	0.7684,	0.772494219,	0.221],
    [0.8410888,	0.8195,	0.806445425,	0.8408,	0.823264467,	0.2018],
    [0.66906214,	0.8085,	0.801328384,	0.8204,	0.810752051,	0.2034],
    [0.268235717,	0.7693,	0.860315761,	0.643,	0.735950555,	0.1044],
    [0.294376572,	0.7731,	0.855691586,	0.657,	0.743296753,	0.1108],
    [0.8968,	0.9,	0.9073,	0.891,	0.8991,	0.091]
]

# UNSW-NB15 F
values_F = [
    [0.325140218,	0.8894,	0.910067397,	0.8642,	0.886540829,	0.0854],
    [0.281920158,	0.5746,	0.649439103,	0.3242,	0.432497332,	0.175],
    [0.40019795,	0.8261,	0.810512283,	0.8512,	0.830358014,	0.199],
    [0.55427253,	0.8183,	0.783033968,	0.8806,	0.828956039,	0.244],
    [0.424282415,	0.7888,	0.871781668,	0.6772,	0.762269248,	0.0996],
    [0.387330914,	0.7689,	0.844655217,	0.659,	0.740366251,	0.1212],
    [0.7494,	0.8987,	0.9151,	0.879,	0.8967,	0.0816]
]

# UNSW-NB15 G
values_G = [
    [0.467436808,	0.7566,	0.775321888,	0.7226,	0.748033126,	0.2094],
    [0.420221504,	0.671,	0.690508021,	0.6198,	0.653246206,	0.2778],
    [0.41195485,	0.6811,	0.681572087,	0.6798,	0.68068489,	0.3176],
    [0.7226962,	0.7554,	0.740308619,	0.7868,	0.762846616,	0.276],
    [0.915690742,	0.6997,	0.706600455,	0.683,	0.694599817,	0.2836],
    [0.971543638,	0.7751,	0.860739575,	0.6564,	0.744808805,	0.1062],
    [0.9969,	0.9127,	0.9144,	0.9106,	0.9125,	0.0852]
]

# UNSW-NB15 R
values_R = [
    [0.907322654,	0.8866,	0.889717742,	0.8826,	0.886144578,	0.1094],
    [0.903318078,	0.8081,	0.830083565,	0.7748,	0.801489604,	0.1586],
    [0.54290617,	0.7513,	0.791193511,	0.6828,	0.733011272,	0.1802],
    [0.8338101,	0.8204,	0.805026657,	0.8456,	0.82481467,	0.2048],
    [0.249713959,	0.7888,	0.871781668,	0.6772,	0.762269248,	0.0996],
    [0.460240275,	0.7743,	0.862351387,	0.6528,	0.743084804,	0.1042],
    [0.9233,	0.9125,	0.9141,	0.9106,	0.9123,	0.0856]
]

# UNSW-NB15 S
values_S = [
    [0.925925926,	0.8808,	0.858974359,	0.9112,	0.88431677,	0.1496],
    [0.783068783,	0.8067,	0.823728098,	0.7804,	0.801478895,	0.167],
    [0.8015873,	0.8281,	0.800953953,	0.8732,	0.835518132,	0.217],
    [0.9047619,	0.8221,	0.786821015,	0.8836,	0.832406971,	0.2394],
    [0.486772487,	0.7122,	0.746057514,	0.6434,	0.690936426,	0.219],
    [0.447089947,	0.7784,	0.876012966,	0.6486,	0.745345897,	0.0918],
    [1,	0.9201,	0.9144,	0.927,	0.9206,	0.0868]
]

# UNSW-NB15 W
values_W = [
    [0.863636364,	0.8886,	0.913756388,	0.8582,	0.885107261,	0.081],
    [0.409090909,	0.7843,	0.787578394,	0.7786,	0.783063462,	0.21],
    [0.8636364,	0.8567,	0.852400711,	0.8628,	0.85756883,	0.1494],
    [0.95454544,	0.8141,	0.778605641,	0.8778,	0.825232678,	0.2496],
    [0.227272727,	0.7671,	0.85948856,	0.6386,	0.73275961,	0.1044],
    [0.136363636,	0.7836,	0.87793177,	0.6588,	0.75274223,	0.0916],
    [1,	0.9066,	0.9129,	0.899,	0.9059,	0.0858]
]

metrics = ['UDR', 'Accuracy', 'Precision', 'Recall', 'F1-Score', 'FPR']

def plot_all_models(unknown_type):

    if unknown_type == 'A':
        values = values_A

    elif unknown_type == 'B':
        values = values_B

    elif unknown_type == 'D':
        values = values_D

    elif unknown_type == 'E':
        values = values_E

    elif unknown_type == 'F':
        values = values_F

    elif unknown_type == 'G':
        values = values_G

    elif unknown_type == 'R':
        values = values_R

    elif unknown_type == 'S':
        values = values_S

    elif unknown_type == 'W':
        values = values_W
    # DL模型    
    plot_model_comparison(models, metrics, values, 
        title=f"UNSW_NB15 (Miss_{unknown_type}) Model Comparison", 
        save_path=f"UNSW_NB15_{unknown_type}_model_comparison_bar.png")


plot_all_models('A')
plot_all_models('B')
plot_all_models('D')
plot_all_models('E')
plot_all_models('F')
plot_all_models('G')
plot_all_models('R')
plot_all_models('S')
plot_all_models('W')

# %%
# CIC Bar
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

def plot_model_comparison(models, metrics, values, title="Model Performance Comparison", figsize=(12, 4), save_path=None):

    # 创建DataFrame以便使用seaborn
    data = []
    for i, model in enumerate(models):
        for j, metric in enumerate(metrics):
            data.append({
                'model': model,
                'metric': metric,
                'value': values[i][j] * 100
            })
    df = pd.DataFrame(data)
    
    # 设置样式
    sns.set(style="whitegrid")
    plt.figure(figsize=figsize)
    
    # 绘制条形图
    ax = sns.barplot(x='model', y='value', hue='metric', data=df)
    
    # 添加标题和标签
    plt.title(title, fontsize=16)
    plt.xlabel('', fontsize=14)
    plt.ylabel('', fontsize=14)
    plt.ylim(0, 100)  # 假设指标值在0-1之间
    
    
    # 调整图例位置
    legend = ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.25), ncol=6, frameon=True)
    
    plt.tight_layout()
    
    # 保存图表
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    # plt.show()

def plot_model_comparison_radar(models, metrics, values, title="model performance radar chart", figsize=(10, 8), save_path=None):

    # 设置图表
    plt.figure(figsize=figsize)
    
    # 计算雷达图的角度
    angles = np.linspace(0, 2*np.pi, len(metrics), endpoint=False).tolist()
    angles += angles[:1]  # 闭合雷达图
    
    # 设置极坐标图
    ax = plt.subplot(111, polar=True)
    
    # 添加每个模型的数据
    for i, model in enumerate(models):
        values_model = values[i]
        values_model += values_model[:1]  # 闭合雷达图
        ax.plot(angles, values_model, 'o-', linewidth=2, label=model)
        ax.fill(angles, values_model, alpha=0.1)
    
    # 设置刻度标签
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(metrics)
    
    # 设置y轴范围
    ax.set_ylim(0, 1)
    
    # 添加图例和标题
    plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
    plt.title(title, fontsize=16)
    
    plt.tight_layout()
    
    # 保存图表
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    # plt.show()

def plot_model_comparison_heatmap(models, metrics, values, title="model performance heatmap", figsize=(10, 8), save_path=None):
    # 创建数据矩阵
    data_matrix = np.array(values)
    
    # 设置图表
    plt.figure(figsize=figsize)
    
    # 绘制热力图
    ax = sns.heatmap(data_matrix, annot=True, fmt=".2f", cmap="YlGnBu",
                     xticklabels=metrics, yticklabels=models, vmin=0, vmax=1)
    
    # 添加标题和标签
    plt.title(title, fontsize=16)
    plt.tight_layout()
    
    # 保存图表
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    # plt.show()

# 模型数据
models = ['RF','SVM','CNN_LSTM','GRU_LSTM','VD','DGA-PSO','LLM']
# CIC Bot
values_Bot = [
    [0.4768	,0.7002	,0.683132089	,0.7468	,0.713548634	,0.3464],
    [0.483	,0.747	,0.787744641	,0.6762	,0.727722772	,0.1822],
    [0.5012	,0.7595	,0.803508772	,0.687	,0.740700809	,0.168],
    [0.0002	,0.5362	,0.665447898	,0.1456	,0.238923531	,0.0732],
    [0.0003	,0.4838	,0.422857143	,0.0888	,0.14677686	,0.1212],
    [0.4985	,0.4899	,0.482385769	,0.2766	,0.351595271	,0.2968],
    [1	,0.7725	,0.7777	,0.7632	,0.7704	,0.2182]
]

# CIC Bruteforce
values_Bruteforce = [
    [0.462	,0.735	,0.76826484	,0.673	,0.717484009	,0.203],
    [0.372	,0.6294	,0.6678	,0.515	,0.5815	,0.2562],
    [0.336	,0.5071	,0.512513218	,0.2908	,0.371060355	,0.2766],
    [0.196	,0.3404	,0.238360656	,0.1454	,0.180621118	,0.4646],
    [0.256	,0.4643	,0.213483146	,0.0266	,0.047305709	,0.098],
    [0.588	,0.4922	,0.48984375	,0.3762	,0.425565611	,0.3918],
    [1	,0.7552	,0.7513	,0.763	,0.7551	,0.2526]
]

# CIC DDoS
values_DDoS = [
    [0.5625	,0.6943	,0.69519791	,0.692	,0.693595269	,0.3034],
    [0.2417	,0.5995	,0.620082066	,0.5138	,0.561959969	,0.3148],
    [0.0003	,0.6412	,0.64526749	,0.6272	,0.636105477	,0.3448],
    [0	,0.4082	,0.389928058	,0.3252	,0.354634678	,0.5088],
    [0.2389	,0.4637	,0.386206897	,0.1232	,0.186808188	,0.1958],
    [0.9976	,0.5281	,0.545307965	,0.3382	,0.417479324	,0.282],
    [1	,0.7707	,0.7747	,0.7634	,0.769	,0.222]
]

# CIC DoS
values_DoS = [
    [0.2135	,0.5465	,0.5861	,0.3166	,0.4111	,0.2236],
    [0.1535	,0.5481	,0.7006	,0.168	,0.271	,0.0718],
    [0.0927	,0.492	,0.488757729	,0.3478	,0.406403365	,0.3638],
    [0.019	,0.3884	,0.20846395	,0.0798	,0.115417992	,0.303],
    [0	,0.4838	,0.422857143	,0.0888	,0.14677686	,0.1212],
    [0.2765	,0.5462	,0.582382311	,0.3266	,0.418503332	,0.2342],
    [0.4148	,0.771	,0.776	,0.762	,0.7689	,0.22]
]

# CIC Infiltration
values_Infiltration = [
    [0.1494	,0.7552	,0.811219512	,0.6652	,0.730989011	,0.1548],
    [0.3568	,0.6788	,0.6744	,0.6914	,0.6828	,0.3338],
    [0.2183	,0.6764	,0.762343843	,0.5126	,0.613011241	,0.1598],
    [0.0004	,0.5018	,0.875	,0.0042	,0.008359873	,0.0006],
    [0.1994	,0.3731	,0.174448435	,0.068	,0.097855807	,0.3218],
    [0.2627	,0.5455	,0.588693957	,0.302	,0.399206874	,0.211],
    [0.797	,0.7763	,0.8049	,0.7294	,0.7653	,0.1769]
]

# CIC SQL_Injection
values_SQL_Injection = [
    [0.492537313	,0.5976	,0.606876916	,0.5542	,0.579343508	,0.359],
    [0.4328	,0.6181	,0.706	,0.5076	,0.5906	,0.2114],
    [0.64179105	,0.6297	,0.636268124	,0.6056	,0.620555385	,0.3462],
    [0.73134327	,0.3632	,0.375816993	,0.414	,0.393985535	,0.6876],
    [0	,0.4504	,0.094771242	,0.0116	,0.020669993	,0.1108],
    [0.567164179	,0.4878	,0.479223433	,0.2814	,0.354586694	,0.3058],
    [1	,0.7506	,0.7441	,0.764	,0.7539	,0.2628]
]


metrics = ['UDR', 'Accuracy', 'Precision', 'Recall', 'F1-Score', 'FPR']

def plot_all_models(unknown_type):

    if unknown_type == 'Bot':
        values = values_Bot

    elif unknown_type == 'Bruteforce':
        values = values_Bruteforce

    elif unknown_type == 'DDoS':
        values = values_DDoS

    elif unknown_type == 'DoS':
        values = values_DoS

    elif unknown_type == 'Infiltration':
        values = values_Infiltration

    elif unknown_type == 'SQL_Injection':
        values = values_SQL_Injection
  
    plot_model_comparison(models, metrics, values, 
        title=f"CICIDS_2018 (Miss_{unknown_type}) Model Comparison", 
        save_path=f"CICIDS_2018_{unknown_type}_model_comparison_bar.png")


plot_all_models('Bot')
plot_all_models('Bruteforce')
plot_all_models('DDoS')
plot_all_models('DoS')
plot_all_models('Infiltration')
plot_all_models('SQL_Injection')
