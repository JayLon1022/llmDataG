# %%
import pandas as pd
from scipy.spatial.distance import cdist
import numpy as np
import os
from tqdm import tqdm
import time
from concurrent.futures import ThreadPoolExecutor

class VDetector:
    def __init__(self, self_radius, coverage_threshold=0.999, initial_detectors=1000):
        self.self_radius = self_radius
        self.coverage_threshold = coverage_threshold
        self.initial_detectors = initial_detectors
        self.detectors = []
        
    def _calculate_detector_radius(self, candidate, self_samples):
        distances = cdist([candidate], self_samples)[0]
        return max(np.min(distances) - self.self_radius, 0)
    
    def _is_covered(self, point, detectors):
        if not detectors:
            return False
        centers = np.array([d[0] for d in detectors])
        radii = np.array([d[1] for d in detectors])
        distances = cdist([point], centers)[0]
        return np.any(distances <= radii)
    
    def generate_detectors(self, self_samples, output_dir):
        # os.makedirs(output_dir, exist_ok=True)
        self_samples = np.array(self_samples)
        dim = self_samples.shape[1]
        max_detectors = min(self.initial_detectors * dim * 10, 50000)
        candidates = np.random.uniform(0, 1, size=(max_detectors, dim))
        
        pbar = tqdm(total=max_detectors, desc=f"Generating detectors (r={self.self_radius})")
        start_time = time.time()
        
        for candidate in candidates:
            if len(self.detectors) >= max_detectors:
                break
            radius = self._calculate_detector_radius(candidate, self_samples)
            if radius > 0 and not self._is_covered(candidate, self.detectors):
                self.detectors.append((candidate, radius))
                pbar.update(1)
                if len(self.detectors) % 100 == 0:
                    coverage = self._estimate_coverage(self_samples)
                    if coverage >= self.coverage_threshold:
                        break
        
        pbar.close()
        
        return self._estimate_coverage(self_samples)
    
    def _estimate_coverage(self, self_samples, sample_size=20000):
        if not self.detectors:
            return 0.0
        dim = len(self.detectors[0][0])
        samples = np.random.uniform(0, 1, size=(sample_size, dim))
        return np.mean([self._is_covered(s, self.detectors) for s in samples])
    
    def predict(self, samples):
        samples = np.array(samples)
        return np.array([self._is_covered(s, self.detectors) for s in samples])
    
    def get_anomaly_scores(self, samples):
        """计算样本到最近检测器的距离作为异常度量"""
        samples = np.array(samples)
        if not self.detectors:
            return np.zeros(len(samples))
        centers = np.array([d[0] for d in self.detectors])
        distances = cdist(samples, centers)
        min_distances = np.min(distances, axis=1)
        return min_distances

def evaluate_performance(self_preds, nonself_preds, unknown_preds, test_self, test_nonself, unknown):
    TP = np.sum(nonself_preds)
    FP = np.sum(self_preds)
    FN = len(test_nonself) - TP
    TN = len(test_self) - FP
    
    metrics = {
        "Accuracy": (TP + TN) / (len(test_self) + len(test_nonself)),
        "Precision": TP / (TP + FP) if (TP + FP) > 0 else 0,
        "Recall": TP / (TP + FN) if (TP + FN) > 0 else 0,
        "FPR": FP / (FP + TN) if (FP + TN) > 0 else 0,
        "Unknown Coverage": np.sum(unknown_preds) / len(unknown)
    }
    metrics["F1"] = 2 * (metrics["Precision"] * metrics["Recall"]) / (metrics["Precision"] + metrics["Recall"]) if (metrics["Precision"] + metrics["Recall"]) > 0 else 0
    
    return metrics

def dual_ablation_study(self_radii, self_counts, unknown_type):
    train_nonself = pd.read_csv(f"../../check/train/unknown_{unknown_type}.csv")
    train_self_full = pd.read_csv("../../check/self/train_self.csv").sample(frac=1, random_state=42)
    test_self = pd.read_csv("../../check/self/test_self.csv").sample(n=5000, random_state=42)
    test_nonself = pd.read_csv("../../check/nonself/test_nonself.csv").sample(n=5000, random_state=42)
    unknown = pd.read_csv(f"../../check/unknown/{unknown_type}.csv")
    
    best_radius = self_radii[len(self_radii)//2]
    best_count = self_counts[len(self_counts)//2]
    best_score = -1
    best_metrics = None
    
    def test_params(params):
        radius, count = params
        train_self = train_self_full.sample(n=min(int(count), len(train_self_full)), random_state=42)
        detector = VDetector(self_radius=radius)
        detector.generate_detectors(train_self, f"temp")
        metrics = evaluate_performance(
            detector.predict(test_self),
            detector.predict(test_nonself),
            detector.predict(unknown),
            test_self, test_nonself, unknown
        )
        return radius, count, metrics
    
    # 并行测试参数组合
    for iteration in range(3):
        radius_range = [max(self_radii[0], best_radius-0.002), min(self_radii[-1], best_radius+0.002)]
        count_range = [max(self_counts[0], best_count-20), min(self_counts[-1], best_count+20)]
        radii_to_test = np.linspace(radius_range[0], radius_range[1], 5)
        counts_to_test = np.linspace(count_range[0], count_range[1], 5, dtype=int)
        
        param_combinations = [(r, c) for r in radii_to_test for c in counts_to_test]
        
        with ThreadPoolExecutor() as executor:
            results = list(executor.map(test_params, param_combinations))
        
        for radius, count, metrics in results:
            score = 0.8 * metrics["F1"] + 0.2 * metrics["Unknown Coverage"]
            if score > best_score:
                best_score = score
                best_radius = radius
                best_count = int(count)
                best_metrics = metrics
    
    # 保存最佳结果
    with open(f"{unknown_type}_best_parameters.txt", "w") as f:
        f.write(f"Best: r={best_radius:.3f}, c={best_count}\n")
        for m, v in best_metrics.items():
            f.write(f"{m}: {v:.2%}\n")
    
    return best_metrics, best_radius, best_count

self_radii = np.arange(0.01, 0.11, 0.01)
self_counts = np.arange(10, 101, 10)

unknown_types = ["bot", "bruteforce", "ddos","dos","infilteration", "sql_injection"]
for unknown_type in unknown_types:
    print(f"\n处理未知类型: {unknown_type}")
    best_metrics, best_radius, best_count = dual_ablation_study(self_radii, self_counts, unknown_type)
    
    train_self_full = pd.read_csv("../../check/self/train_self.csv").sample(frac=1, random_state=42)
    train_self = train_self_full.sample(n=min(best_count, len(train_self_full)), random_state=42)
    final_detector = VDetector(self_radius=best_radius)
    final_detector.generate_detectors(train_self, f"{unknown_type}/final_model")
    
    test_self = pd.read_csv("../../check/self/test_self.csv").sample(n=5000, random_state=42)
    test_nonself = pd.read_csv("../../check/nonself/test_nonself.csv").sample(n=5000, random_state=42)
    unknown = pd.read_csv(f"../../check/unknown/{unknown_type}.csv")
    
    final_metrics = evaluate_performance(
        final_detector.predict(test_self),
        final_detector.predict(test_nonself),
        final_detector.predict(unknown),
        test_self, test_nonself, unknown
    )
# Out:
# 处理未知类型: bot
# Generating detectors (r=0.058):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:07<?, ?it/s]
# Generating detectors (r=0.062000000000000006):   0%|          | 0/50000 [01:17<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:18<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:23<?, ?it/s]
# Generating detectors (r=0.062000000000000006):   0%|          | 0/50000 [01:23<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:24<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:24<1175:06:52, 84.61s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:25<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:30<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:32<641:09:01, 46.16s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:33<652:12:39, 46.96s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:34<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:34<1310:46:52, 94.38s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:35<1323:38:48, 95.30s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 2/50000 [01:34<653:14:47, 47.04s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 1/50000 [01:34<1309:34:06, 94.29s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:35<663:55:09, 47.80s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:36<673:17:12, 48.48s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:37<1353:32:42, 97.46s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:38<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:40<697:12:26, 50.20s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 1/50000 [01:41<1410:45:52, 101.58s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:42<1429:11:30, 102.90s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:46<736:17:45, 53.02s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 3/50000 [01:52<521:30:48, 37.55s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [00:04<34:19:39,  2.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.062):   0%|          | 0/50000 [01:39<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:40<1389:49:34, 100.07s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:40<1394:24:45, 100.40s/it]
#
#
#
#
#
#
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:41<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:41<?, ?it/s]
# Generating detectors (r=0.064):   0%|          | 1/50000 [01:41<1413:04:53, 101.74s/it]
# Generating detectors (r=0.063):   0%|          | 1/50000 [01:42<1420:03:34, 102.25s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:43<717:36:22, 51.67s/it]
# Generating detectors (r=0.063):   0%|          | 0/50000 [01:42<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:44<1448:48:57, 104.32s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:44<1456:40:33, 104.88s/it]
# Generating detectors (r=0.062):   0%|          | 2/50000 [01:44<726:51:57, 52.34s/it]
# Generating detectors (r=0.064):   0%|          | 0/50000 [01:44<?, ?it/s]
# Generating detectors (r=0.064):   0%|          | 1/50000 [01:46<1472:54:05, 106.05s/it]
# Generating detectors (r=0.062):   0%|          | 1/50000 [01:46<1483:35:12, 106.82s/it]
# Generating detectors (r=0.064):   0%|          | 1/50000 [01:47<1493:17:33, 107.52s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:49<1518:38:21, 109.34s/it]
# Generating detectors (r=0.063):   0%|          | 1/50000 [01:49<1517:45:20, 109.28s/it]
# Generating detectors (r=0.063):   0%|          | 2/50000 [01:51<777:19:27, 55.97s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:52<781:32:49, 56.27s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:56<808:24:11, 58.21s/it]
# Generating detectors (r=0.062):   0%|          | 1/50000 [01:56<1622:58:46, 116.86s/it]
# Generating detectors (r=0.062):   0%|          | 2/50000 [01:59<829:39:05, 59.74s/it]
# Generating detectors (r=0.064):   0%|          | 1/50000 [02:05<1745:49:27, 125.70s/it]
# Generating detectors (r=0.063):   0%|          | 2/50000 [02:06<881:54:21, 63.50s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.063):   0%|          | 0/50000 [01:19<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:31<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:34<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:34<1316:48:19, 94.81s/it]
# Generating detectors (r=0.063):   0%|          | 1/50000 [01:36<1337:11:27, 96.28s/it]
# Generating detectors (r=0.062):   0%|          | 1/50000 [01:37<1354:35:45, 97.53s/it]
# Generating detectors (r=0.062):   0%|          | 0/50000 [01:40<?, ?it/s]
# Generating detectors (r=0.064):   0%|          | 1/50000 [01:40<1399:43:19, 100.78s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:43<1441:37:18, 103.80s/it]
# Generating detectors (r=0.062):   0%|          | 2/50000 [01:43<721:56:03, 51.98s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:45<1463:04:50, 105.34s/it]
# Generating detectors (r=0.063):   0%|          | 1/50000 [01:45<1470:53:19, 105.91s/it]
# Generating detectors (r=0.064):   0%|          | 1/50000 [01:46<1485:50:38, 106.98s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:49<1520:20:56, 109.47s/it]
# Generating detectors (r=0.064):   0%|          | 1/50000 [01:49<1521:44:53, 109.57s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:51<1550:58:02, 111.67s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:52<780:14:20, 56.18s/it]
# Generating detectors (r=0.064):   0%|          | 0/50000 [01:51<?, ?it/s]
# Generating detectors (r=0.062):   0%|          | 2/50000 [01:52<781:12:32, 56.25s/it]
# Generating detectors (r=0.063):   0%|          | 1/50000 [01:52<1561:31:22, 112.43s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:56<806:45:36, 58.09s/it]
# Generating detectors (r=0.063):   0%|          | 1/50000 [01:59<1656:18:34, 119.26s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [02:07<881:55:05, 63.50s/it]
# Generating detectors (r=0.062):   0%|          | 2/50000 [02:09<900:55:28, 64.87s/it]
# Generating detectors (r=0.064):   0%|          | 3/50000 [02:26<676:38:20, 48.72s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [00:01<17:22:13,  1.25s/it]
# 处理未知类型: bruteforce
# Generating detectors (r=0.058):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:19<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:22<1141:04:01, 82.16s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 0/50000 [01:22<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:24<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:24<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:28<1224:26:52, 88.16s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:29<618:53:46, 44.56s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:29<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:32<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:34<?, ?it/s]
# Generating detectors (r=0.062000000000000006):   0%|          | 0/50000 [01:33<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:35<1321:37:07, 95.16s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:34<1316:40:37, 94.80s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:38<683:27:31, 49.21s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 2/50000 [01:38<684:04:59, 49.26s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:39<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:42<1424:20:39, 102.55s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:42<711:00:32, 51.19s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 2/50000 [01:42<710:38:30, 51.17s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:43<718:40:37, 51.75s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 2/50000 [01:44<727:27:24, 52.38s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:48<754:46:09, 54.35s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:50<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:53<787:01:29, 56.67s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:56<810:18:21, 58.34s/it]
# Generating detectors (r=0.057):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:43<1443:50:47, 103.96s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:46<1481:14:55, 106.65s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:50<1535:31:49, 110.56s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:50<1540:58:06, 110.95s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:53<1578:02:00, 113.62s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:54<1584:44:21, 114.10s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:54<1595:35:17, 114.88s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:54<1596:05:31, 114.92s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [01:57<812:44:12, 58.52s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:58<1643:52:43, 118.36s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [02:00<1671:27:06, 120.35s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [02:00<1677:16:32, 120.77s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [02:01<1692:19:41, 121.85s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [02:01<845:26:20, 60.87s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [02:03<1710:25:56, 123.15s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [02:05<1737:03:58, 125.07s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [02:04<1723:35:29, 124.10s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:06<879:11:43, 63.30s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:06<881:22:21, 63.46s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:08<889:43:55, 64.06s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [02:08<1791:06:52, 128.96s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [02:10<1807:44:34, 130.16s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [02:10<907:35:30, 65.35s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [02:15<942:29:18, 67.86s/it]
# Generating detectors (r=0.058):   0%|          | 3/50000 [02:45<764:50:32, 55.07s/it]
# Generating detectors (r=0.057):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:42<1429:07:25, 102.90s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:46<1473:36:04, 106.10s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:53<1572:49:37, 113.25s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:52<1559:45:54, 112.31s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:55<1601:49:04, 115.33s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:55<1606:55:57, 115.70s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:56<1614:40:46, 116.26s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:57<1633:45:20, 117.63s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:58<1645:22:39, 118.47s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:57<1634:42:52, 117.70s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:58<1643:00:11, 118.30s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:01<842:26:36, 60.66s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [02:01<1685:57:45, 121.39s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:03<854:47:33, 61.55s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:04<862:55:00, 62.13s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [02:06<1751:44:48, 126.13s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:06<876:54:46, 63.14s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [02:06<881:03:05, 63.44s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [02:06<1751:41:37, 126.12s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [02:07<1767:58:33, 127.30s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:09<900:59:28, 64.87s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [02:10<908:33:40, 65.42s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:11<913:01:11, 65.74s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [02:11<915:50:16, 65.94s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [02:12<917:27:19, 66.06s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [00:01<8:19:58,  1.67it/s]
# 处理未知类型: ddos
# Generating detectors (r=0.058):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:20<1118:39:44, 80.55s/it]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:24<?, ?it/s]
# Generating detectors (r=0.062000000000000006):   0%|          | 0/50000 [01:24<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:28<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:28<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:29<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:30<?, ?it/s]
# Generating detectors (r=0.062000000000000006):   0%|          | 1/50000 [01:30<1261:09:54, 90.81s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:31<1277:21:19, 91.97s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:32<1289:14:25, 92.83s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:32<1280:29:22, 92.20s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 0/50000 [01:31<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:35<1319:45:14, 95.02s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:35<1323:52:00, 95.32s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:36<1336:00:47, 96.19s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:36<1339:46:55, 96.47s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:37<1355:23:01, 97.59s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:38<687:10:33, 49.48s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 1/50000 [01:39<1379:42:00, 99.34s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:41<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:41<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:42<714:23:13, 51.44s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:43<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:43<721:35:29, 51.96s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 2/50000 [01:47<746:14:27, 53.73s/it]
# Generating detectors (r=0.056):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:44<1445:19:39, 104.07s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:52<782:54:23, 56.37s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:54<1594:37:16, 114.82s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:56<1612:33:21, 116.11s/it]
# Generating detectors (r=0.056):   0%|          | 2/50000 [01:56<810:00:41, 58.32s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:56<1613:46:25, 116.19s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:58<825:22:01, 59.43s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [02:01<843:19:42, 60.72s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [02:02<1700:18:25, 122.42s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [02:02<1699:37:31, 122.38s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [02:03<1710:16:50, 123.14s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [02:04<1725:08:52, 124.21s/it]
# Generating detectors (r=0.056):   0%|          | 2/50000 [02:05<868:28:29, 62.53s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [02:04<865:37:32, 62.33s/it]
# Generating detectors (r=0.056):   0%|          | 2/50000 [02:06<877:23:02, 63.17s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:06<878:35:32, 63.26s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [02:08<890:04:11, 64.09s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [02:08<1785:03:45, 128.53s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [02:09<1801:42:36, 129.73s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [02:10<1810:16:33, 130.34s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:12<918:38:36, 66.14s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:13<926:02:38, 66.68s/it]
# Generating detectors (r=0.056):   0%|          | 2/50000 [02:17<953:45:02, 68.67s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [02:18<1920:57:23, 138.31s/it]
# Generating detectors (r=0.058):   0%|          | 3/50000 [02:31<699:59:31, 50.40s/it]
# Generating detectors (r=0.054):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.054):   0%|          | 1/50000 [01:39<1382:49:22, 99.57s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:46<1485:42:15, 106.97s/it]
# Generating detectors (r=0.054):   0%|          | 1/50000 [01:51<1545:37:52, 111.29s/it]
# Generating detectors (r=0.055):   0%|          | 1/50000 [01:51<1551:18:38, 111.70s/it]
# Generating detectors (r=0.054):   0%|          | 1/50000 [01:52<1564:13:24, 112.63s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:51<1554:30:10, 111.93s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:54<1584:49:22, 114.11s/it]
# Generating detectors (r=0.055):   0%|          | 1/50000 [01:54<1595:23:36, 114.87s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:56<1622:03:28, 116.79s/it]
# Generating detectors (r=0.055):   0%|          | 1/50000 [02:01<1690:06:53, 121.69s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [02:00<1680:12:50, 120.98s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [02:01<842:36:04, 60.67s/it]
# Generating detectors (r=0.054):   0%|          | 1/50000 [02:03<1719:32:13, 123.81s/it]
# Generating detectors (r=0.056):   0%|          | 2/50000 [02:03<860:09:47, 61.93s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [02:03<1711:47:36, 123.25s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [02:04<1734:23:41, 124.88s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:04<866:42:02, 62.40s/it]
# Generating detectors (r=0.054):   0%|          | 1/50000 [02:06<1758:13:13, 126.59s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:06<878:28:43, 63.25s/it]
# Generating detectors (r=0.056):   0%|          | 2/50000 [02:08<889:05:38, 64.02s/it]
# Generating detectors (r=0.056):   0%|          | 2/50000 [02:09<897:08:29, 64.60s/it]
# Generating detectors (r=0.055):   0%|          | 2/50000 [02:09<899:49:59, 64.79s/it]
# Generating detectors (r=0.055):   0%|          | 2/50000 [02:10<904:55:56, 65.16s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:09<899:36:56, 64.77s/it]
# Generating detectors (r=0.057):   0%|          | 3/50000 [02:39<736:06:24, 53.00s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [00:01<17:32:11,  1.26s/it]
# 处理未知类型: dos
# Generating detectors (r=0.058):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:09<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:12<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:19<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:20<?, ?it/s]
# Generating detectors (r=0.062000000000000006):   0%|          | 0/50000 [01:22<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:25<1188:22:27, 85.56s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:25<1184:30:55, 85.29s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:26<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:28<1235:39:39, 88.97s/it]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:29<?, ?it/s]
# Generating detectors (r=0.062000000000000006):   0%|          | 2/50000 [01:32<639:40:26, 46.06s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:33<648:18:08, 46.68s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 1/50000 [01:33<1300:21:38, 93.63s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 1/50000 [01:33<1301:49:09, 93.73s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:35<1319:35:49, 95.01s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:37<676:51:52, 48.74s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:41<702:36:58, 50.59s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:43<1435:19:04, 103.34s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:44<723:35:42, 52.10s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:46<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:49<761:09:22, 54.81s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:48<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:50<768:36:59, 55.34s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:50<768:17:47, 55.32s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 0/50000 [01:51<?, ?it/s]
# Generating detectors (r=0.057):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:18<1094:10:41, 78.78s/it]
# Generating detectors (r=0.057):   0%|          | 0/50000 [01:22<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:25<1192:51:34, 85.89s/it]
# Generating detectors (r=0.057):   0%|          | 0/50000 [01:29<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:29<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:30<1255:14:31, 90.38s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:30<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:31<636:12:06, 45.81s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:34<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:34<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:35<666:37:59, 48.00s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [01:37<677:31:24, 48.78s/it]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:37<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:37<1358:52:29, 97.84s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:37<679:10:29, 48.90s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:37<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:39<1383:12:11, 99.59s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:41<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:41<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:42<713:38:57, 51.38s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:43<721:56:30, 51.98s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:46<736:55:38, 53.06s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:46<739:37:39, 53.26s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [01:50<766:19:24, 55.18s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:52<781:05:16, 56.24s/it]
# Generating detectors (r=0.055):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:44<1445:58:01, 104.11s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:43<1438:07:16, 103.55s/it]
# Generating detectors (r=0.055):   0%|          | 1/50000 [01:51<1544:30:30, 111.21s/it]
# Generating detectors (r=0.055):   0%|          | 2/50000 [01:54<795:42:35, 57.29s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [01:54<792:31:26, 57.06s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:55<1606:49:51, 115.69s/it]
# Generating detectors (r=0.055):   0%|          | 1/50000 [01:56<1616:29:56, 116.39s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [02:00<834:09:10, 60.06s/it]
# Generating detectors (r=0.055):   0%|          | 1/50000 [02:01<1680:59:34, 121.03s/it]
# Generating detectors (r=0.055):   0%|          | 1/50000 [02:02<1696:08:49, 122.13s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [02:01<1689:52:01, 121.67s/it]
# Generating detectors (r=0.056):   0%|          | 2/50000 [02:05<873:11:41, 62.87s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:06<876:21:13, 63.10s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:08<893:23:43, 64.33s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [02:10<1814:13:18, 130.63s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [02:11<1824:56:54, 131.40s/it]
# Generating detectors (r=0.056):   0%|          | 2/50000 [02:12<920:01:54, 66.24s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:12<921:09:43, 66.33s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:12<921:49:46, 66.37s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [02:13<927:28:19, 66.78s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:14<933:11:57, 67.19s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:14<936:53:27, 67.46s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [02:16<947:20:24, 68.21s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [02:23<1994:15:31, 143.59s/it]
# Generating detectors (r=0.056):   0%|          | 3/50000 [02:50<790:48:25, 56.94s/it]
# Generating detectors (r=0.055):   0%|          | 1/50000 [00:01<17:07:49,  1.23s/it]
# 处理未知类型: infilteration
# Generating detectors (r=0.058):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:19<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:19<1107:51:21, 79.77s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 0/50000 [01:18<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:21<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:28<?, ?it/s]
# Generating detectors (r=0.062000000000000006):   0%|          | 1/50000 [01:28<1235:24:20, 88.95s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 1/50000 [01:30<1249:58:32, 90.00s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:31<1266:40:10, 91.20s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:31<?, ?it/s]
# Generating detectors (r=0.062000000000000006):   0%|          | 0/50000 [01:31<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:32<643:39:16, 46.34s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:35<1328:50:27, 95.68s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:35<1325:39:20, 95.45s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:38<1366:19:02, 98.38s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:38<1361:35:06, 98.04s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:40<701:10:14, 50.49s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:41<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:41<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:41<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:43<721:06:02, 51.92s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:45<730:08:13, 52.57s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:45<729:56:07, 52.56s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 1/50000 [01:46<1486:04:26, 107.00s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:51<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:57<818:14:36, 58.92s/it]
# Generating detectors (r=0.056):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.056):   0%|          | 0/50000 [01:20<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:23<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:27<1213:44:48, 87.39s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:29<1243:54:53, 89.56s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:32<1281:21:20, 92.26s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:33<1297:26:45, 93.42s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:32<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:32<1287:13:59, 92.68s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:33<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:34<656:02:51, 47.24s/it]
# Generating detectors (r=0.056):   0%|          | 2/50000 [01:35<663:05:54, 47.75s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:37<1356:15:06, 97.65s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:38<1364:00:57, 98.21s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:37<679:53:58, 48.95s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:37<680:07:15, 48.97s/it]
# Generating detectors (r=0.057):   0%|          | 0/50000 [01:39<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:39<689:04:57, 49.62s/it]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:41<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:44<?, ?it/s]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:45<1459:23:43, 105.08s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:45<732:02:32, 52.71s/it]
# Generating detectors (r=0.057):   0%|          | 0/50000 [01:46<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:46<741:44:29, 53.41s/it]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:47<?, ?it/s]
# Generating detectors (r=0.056):   0%|          | 0/50000 [01:48<?, ?it/s]
# Generating detectors (r=0.056):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:39<1376:57:20, 99.14s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:47<1493:55:16, 107.56s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:49<1516:02:43, 109.16s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:52<1568:02:21, 112.90s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:53<1573:29:52, 113.29s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:54<1589:47:53, 114.47s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:56<1612:42:20, 116.12s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:58<1638:57:01, 118.01s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:59<1660:48:36, 119.58s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:59<1653:54:39, 119.08s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [02:02<848:14:06, 61.08s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:01<846:50:33, 60.98s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [02:01<845:46:32, 60.90s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [02:02<1701:31:46, 122.51s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [02:04<1735:11:44, 124.94s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [02:05<1743:46:53, 125.55s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [02:05<1744:01:52, 125.57s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:08<890:13:55, 64.10s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [02:08<1784:39:48, 128.50s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [02:09<900:36:28, 64.85s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [02:12<1840:37:51, 132.53s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [02:13<925:42:06, 66.65s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:16<949:30:51, 68.37s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [02:19<1943:59:25, 139.97s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [02:27<1021:05:19, 73.52s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [00:01<17:41:43,  1.27s/it]
# 处理未知类型: sql_injection
# Generating detectors (r=0.058):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:10<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:13<?, ?it/s]
# Generating detectors (r=0.062000000000000006):   0%|          | 0/50000 [01:13<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:22<1146:22:54, 82.54s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:22<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 0/50000 [01:23<?, ?it/s]
#
#
#
#
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:25<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:28<1235:47:43, 88.98s/it]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:30<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:32<643:59:51, 46.37s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:33<1291:59:50, 93.03s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 1/50000 [01:32<1285:56:25, 92.59s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:34<1310:13:22, 94.34s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:34<653:34:41, 47.06s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 1/50000 [01:34<1314:30:35, 94.65s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:37<1357:03:43, 97.71s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 2/50000 [01:37<678:51:48, 48.88s/it]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:39<?, ?it/s]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:39<692:12:17, 49.84s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:40<701:03:44, 50.48s/it]
# Generating detectors (r=0.061000000000000006):   0%|          | 2/50000 [01:44<724:43:04, 52.18s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:47<744:08:58, 53.58s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 1/50000 [01:47<1499:55:09, 108.00s/it]
# Generating detectors (r=0.062000000000000006):   0%|          | 0/50000 [01:48<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:49<?, ?it/s]
# Generating detectors (r=0.056):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.056):   0%|          | 2/50000 [00:06<47:12:15,  3.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.056):   0%|          | 0/50000 [01:21<?, ?it/s]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:21<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:23<?, ?it/s]
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:25<1187:46:32, 85.52s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:24<?, ?it/s]
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:28<1226:35:22, 88.32s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 0/50000 [01:27<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:30<1253:09:40, 90.23s/it]
# Generating detectors (r=0.058):   0%|          | 0/50000 [01:30<?, ?it/s]
# Generating detectors (r=0.057):   0%|          | 0/50000 [01:33<?, ?it/s]
# Generating detectors (r=0.056):   0%|          | 0/50000 [01:35<?, ?it/s]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:36<1334:28:45, 96.08s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:36<670:46:09, 48.30s/it]
# Generating detectors (r=0.056):   0%|          | 2/50000 [01:37<677:06:19, 48.75s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 1/50000 [01:36<1339:39:33, 96.46s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:37<1353:07:55, 97.43s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [01:38<684:22:13, 49.28s/it]
# Generating detectors (r=0.060000000000000005):   0%|          | 0/50000 [01:38<?, ?it/s]
# Generating detectors (r=0.057):   0%|          | 0/50000 [01:41<?, ?it/s]
# Generating detectors (r=0.060000000000000005):   0%|          | 2/50000 [01:40<699:48:21, 50.39s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:42<711:57:47, 51.26s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [01:45<730:10:30, 52.57s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [01:46<739:28:36, 53.24s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:50<1528:23:50, 110.05s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [01:52<777:49:05, 56.01s/it]
# Generating detectors (r=0.055):   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:41<1406:39:09, 101.28s/it]
# Generating detectors (r=0.055):   0%|          | 1/50000 [01:48<1508:58:48, 108.65s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [01:50<1531:10:28, 110.25s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:51<1547:20:01, 111.41s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [01:53<1572:12:12, 113.20s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:53<1582:30:11, 113.94s/it]
# Generating detectors (r=0.055):   0%|          | 1/50000 [01:54<1593:16:32, 114.72s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [01:58<1652:34:19, 118.99s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [01:59<1665:20:56, 119.91s/it]
# Generating detectors (r=0.055):   0%|          | 1/50000 [02:03<1712:34:57, 123.31s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [02:04<1727:30:51, 124.38s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [02:03<1717:17:46, 123.65s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [02:04<1723:59:53, 124.13s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 2/50000 [02:04<862:33:19, 62.11s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [02:05<1742:32:45, 125.47s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [02:06<1753:27:27, 126.25s/it]
# Generating detectors (r=0.058):   0%|          | 1/50000 [02:07<1766:38:03, 127.20s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [02:08<892:27:35, 64.26s/it]
# Generating detectors (r=0.056):   0%|          | 2/50000 [02:11<915:44:01, 65.94s/it]
# Generating detectors (r=0.055):   0%|          | 2/50000 [02:14<934:55:05, 67.32s/it]
# Generating detectors (r=0.057):   0%|          | 1/50000 [02:16<1901:57:21, 136.94s/it]
# Generating detectors (r=0.056):   0%|          | 1/50000 [02:19<1943:27:03, 139.93s/it]
# Generating detectors (r=0.059000000000000004):   0%|          | 1/50000 [02:21<1967:57:16, 141.70s/it]
# Generating detectors (r=0.057):   0%|          | 2/50000 [02:24<1001:31:12, 72.11s/it]
# Generating detectors (r=0.055):   0%|          | 2/50000 [02:30<1044:04:13, 75.18s/it]
# Generating detectors (r=0.058):   0%|          | 2/50000 [00:01<8:50:50,  1.57it/s]
